# %% [markdown]
# <a href="https://colab.research.google.com/github/onengis/Intro-to-programming-with-Nakov/blob/master/Omubo_Onengibofa_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b0c687fa5b46> in <module>
#       1 file_id = 'https://docs.google.com/spreadsheets/d/1Sf_65xbvKTuZ5zGvppYUS3e1c1yLT-pH/edit#gid=234610782'
# ----> 2 downloaded = drive.CreateFile({'Oil well': file_id})
#       3 downloaded.GetContentFile('exported.xlsx')
#
# NameError: name 'drive' is not defined

# %%
import openpyxl
PATH_TO_EXCEL_FILE = "/content/drive/MyDrive/Oil well.xlsx"
# !pip install -q xlrd
df = pd.read_excel(PATH_TO_EXCEL_FILE)
df
# Out:
#      Oil well operation parameters (2013 - 2021 y). Well № 807  \
# 0                                                   NaN
# 1                                                  Date
# 2                                   2013-01-01 00:00:00
# 3                                   2013-01-02 00:00:00
# 4                                   2013-01-03 00:00:00
# ...                                                 ...
# 2936                                2021-01-14 00:00:00
# 2937                                2021-01-15 00:00:00
# 2938                                2021-01-16 00:00:00
# 2939                                2021-01-17 00:00:00
# 2940                                2021-01-18 00:00:00
#
#                  Unnamed: 1                 Unnamed: 2             Unnamed: 3  \
# 0                       NaN                        NaN                    NaN
# 1     \nOil volume (m3/day)  Volume of liquid (m3/day)  \nGas volume (m3/day)
# ...

# %%
row = [0]
df.drop(index=row)
# Out:
#      Oil well operation parameters (2013 - 2021 y). Well № 807  \
# 1                                                  Date
# 2                                   2013-01-01 00:00:00
# 3                                   2013-01-02 00:00:00
# 4                                   2013-01-03 00:00:00
# 5                                   2013-01-04 00:00:00
# ...                                                 ...
# 2936                                2021-01-14 00:00:00
# 2937                                2021-01-15 00:00:00
# 2938                                2021-01-16 00:00:00
# 2939                                2021-01-17 00:00:00
# 2940                                2021-01-18 00:00:00
#
#                  Unnamed: 1                 Unnamed: 2             Unnamed: 3  \
# 1     \nOil volume (m3/day)  Volume of liquid (m3/day)  \nGas volume (m3/day)
# 2                        49                         70                  13055
# ...

# %%
df.drop(index=row, inplace=True)

# %%
row = []
df.drop(index=row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-e803695a0788> in <module>
# ----> 1 row = [null]
#       2 df.drop(index=row)
#
# NameError: name 'null' is not defined

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Oil well operation parameters (2013 - 2021 y). Well № 807  \
# 1                                                  Date
# 2                                   2013-01-01 00:00:00
# 3                                   2013-01-02 00:00:00
# 4                                   2013-01-03 00:00:00
# 5                                   2013-01-04 00:00:00
# ...                                                 ...
# 2936                                2021-01-14 00:00:00
# 2937                                2021-01-15 00:00:00
# 2938                                2021-01-16 00:00:00
# 2939                                2021-01-17 00:00:00
# 2940                                2021-01-18 00:00:00
#
#                  Unnamed: 1                 Unnamed: 2             Unnamed: 3  \
# 1     \nOil volume (m3/day)  Volume of liquid (m3/day)  \nGas volume (m3/day)
# 2                        49                         70                  13055
# ...

# %%
df.describe(include = "all")
# Out:
#        Oil well operation parameters (2013 - 2021 y). Well № 807  Unnamed: 1  \
# count                                                2940               2940
# unique                                               2940                 51
# top                                                  Date                 14
# freq                                                    1                287
#
#         Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# count         2940        2940        2940        2940        2940
# unique          89        1149          73          59          19
# top             57        3684          43          75          24
# freq           205          33         169         325        2002
#
#         Unnamed: 7  Unnamed: 8
# count         2940        2940
# unique         276         116
# top           2122         157
# freq           231          26

# %%
df.isna
# Out:
# <bound method DataFrame.isna of      Oil well operation parameters (2013 - 2021 y). Well № 807  \
# 1                                                  Date
# 2                                   2013-01-01 00:00:00
# 3                                   2013-01-02 00:00:00
# 4                                   2013-01-03 00:00:00
# 5                                   2013-01-04 00:00:00
# ...                                                 ...
# 2936                                2021-01-14 00:00:00
# 2937                                2021-01-15 00:00:00
# 2938                                2021-01-16 00:00:00
# 2939                                2021-01-17 00:00:00
# 2940                                2021-01-18 00:00:00
#
#                  Unnamed: 1                 Unnamed: 2             Unnamed: 3  \
# 1     \nOil volume (m3/day)  Volume of liquid (m3/day)  \nGas volume (m3/day)
# 2                        49                         70                  13055
# ...
